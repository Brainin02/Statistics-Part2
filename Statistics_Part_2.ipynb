# %% [markdown]
# 1. What is hypothesis testing in statistics?
#
# ans. Hypothesis testing in statistics is a method used to make decisions or inferences about a population based on sample data. It helps you determine whether there is enough evidence in your sample to support a specific claim about the population.
#
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#
#  ans. Null Hypothesis (Ho)
#
#  It’s the default assumption or the status quo.
#
# It usually suggests no effect, no difference, or no relationship.
#
# You test this hypothesis indirectly — by trying to find evidence against it.
#
# Alternative Hypothesis (H1​or 𝐻a)
# It’s what you're trying to find evidence for.
#
# It suggests there is an effect, difference, or relationship.
#
# If your data provides strong enough evidence, you reject 𝐻0in favor of Ha  .
#
#  3. What is the significance level in hypothesis testing, and why is it important
#
#  ans. The significance level, often denoted by α, is a threshold in hypothesis testing that helps you decide whether to reject the null hypothesis.
#
#  Why It’s Important:
# Sets the bar for evidence:
# It defines how strong your evidence (p-value) must be to reject the null hypothesis.
#
# Controls error risk:
# A lower α means you're being more cautious about declaring an effect when there might not be one.
#
# Guides interpretation:
#
# If 𝑝≤𝛼: Reject Ho(statistically significant result)
#
# If 𝑝>𝛼: Fail to reject Ho
#   (not enough evidence)
#
#
# 4. What does a P-value represent in hypothesis testing?
#
# ans. The p-value is the probability of getting your observed results (or something more extreme) assuming the null hypothesis is true.
#
# 5. How do you interpret the P-value in hypothesis testing?
#
#  ans. The p-value represents the probability of observing your sample results, or something more extreme, assuming that the null hypothesis (Ho) is true.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing ?
#
# ans. Type I Error (False Positive)
# You reject the null hypothesis, but it's actually true.
#
# You're saying there is an effect or difference when there isn’t one.
#
# This is controlled by your significance level (α) — usually 0.0
#
# Type II Error (False Negative)
# You fail to reject the null hypothesis, but it's actually false.
#
# You're saying there is no effect, but there actually is one.
#
# This error is related to power (1 - β), and often harder to control.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#
# ans. wo-Tailed Test
# Used when you want to detect any difference from the null — higher or lower.
#
# The alternative hypothesis (Ha) is non-directional.
#
# One-Tailed Test
# Used when you're only interested in a difference in one specific direction.
#
# The alternative hypothesis (Ha) is directional.
#
# 8. What is the Z-test, and when is it used in hypothesis testing ?
#
# ans. A Z-test is a type of hypothesis test used to determine whether there is a significant difference between sample data and a population parameter (like the mean or proportion), when the population standard deviation is known.
#
# It uses the Z-distribution (standard normal distribution) to calculate probabilities.
#
# Use a Z-test when all of the following are true:
#
# The population standard deviation (σ) is known.
#
# The sample size is large (usually n≥30), or the population is normally distributed.
#
# You're testing the mean or proportion.
#
# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing ?
#
# ans. Z=x-µ/𝜎/√n
#
# Where:
#
# x = sample mean
#
# μ = population mean (under the null hypothesis)
#
# σ = population standard deviation
#
# n = sample size
#
# What the Z-score Represents:
# It tells you how many standard errors your sample mean is from the population mean under the null hypothesis.
#
# A higher absolute Z-score means your result is more unusual/extreme if Ho is true.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution.
#
# ans. The t-distribution is a probability distribution used in hypothesis testing when the sample size is small and/or the population standard deviation is unknown.
#
# It looks similar to the normal distribution, but:
#
# It has fatter tails, meaning more probability is in the extremes.
#
# It's wider when sample size is small (more variability).
#
# As the sample size increases, it approaches the normal distribution.
#
# Use the t-distribution when:
#
# The sample size is small (typically n< 30).
#
# The population standard deviation σ is unknown.
#
# The data is roughly normally distributed (or the sample is large enough for the Central Limit Theorem to apply).
#
# 11. What is the difference between a Z-test and a T-test?
#
# ans. Z-test:
# When to Use:
#
# Typically used for large sample sizes (usually n≥30).
#
# Can be used when the population standard deviation (σ) is known.
#
# Test Statistic:
#
# Uses the Z-score for the test statistic.
#
# Distribution:
#
# Assumes the normal distribution (Z-distribution).
#
# Formula:
#
# The formula for the Z-test is:
#
# Z= x −μ / 𝜎÷√n
#
#
# Use Cases:
#
# One-sample Z-test (testing the mean of one sample)
#
# Z-test for proportions
#
# When to Use:
#
# Typically used for small sample sizes (usually
# 𝑛
# <
# 30
# n< 30).
#
# Used when the population standard deviation is unknown and needs to be estimated from the sample.
#
# Test Statistic:
#
# Uses the T-score for the test statistic.
#
# Distribution:
#
# Assumes the t-distribution (with fatter tails, especially for small samples).
#
# Formula:
#
# The formula for the T-test is:
# T= X−μ
#    –--
#     s÷√n
#
#    Where:
#
# 𝑥 = sample mean
#
# μ = population mean (under the null hypothesis)
#
# s = sample standard deviation (used instead of σ)
#
#
# n = sample size
#
# Use Cases:
#
# One-sample t-test (testing the mean of one sample)
#
# Two-sample t-test (comparing means of two independent groups)
#
# Paired t-test (comparing means of the same group before and after treatment)
#
# Key Differences:
# Z-test is for large samples and when the population standard deviation is known.
#
# T-test is for small samples or when the population standard deviation is unknown.
# ​
# 12. What is the T-test, and how is it used in hypothesis testing?
#
# ans. The T-test is a statistical test used to determine whether there's a significant difference between the means of two groups, which may be related in certain features. It is commonly used in hypothesis testing to infer if the observed differences are likely due to chance or if they're statistically significant.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#
# ans.
# Both are based on the same logic: comparing an observed sample mean to a population mean (or another sample mean) and determining whether the difference is statistically significant.
#
# Both use a test statistic (Z or T) and rely on sampling distributions (normal for Z, T-distribution for T).
#
# Both produce a p-value which is used to accept or reject the null hypothesis.
#
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#
# ans. A confidence interval gives an estimated range of values which is likely to include the true population parameter. It's expressed with a confidence level — typically 95%, though 90% or 99% are also common.
#
# 🔍 Interpreting a Confidence Interval
# Say you calculate a 95% confidence interval for a population mean and get:[65.2, 72.8]
# This means you are 95% confident that the true population mean lies somewhere between 65.2 and 72.8.
#
# Important: It doesn't mean there's a 95% chance the true mean is in the interval — it means that if you repeated the experiment 100 times, about 95 out of 100 intervals would capture the true parameter.
#
# 15. What is the margin of error, and how does it affect the confidence interval?
#
# ans. The margin of error is the plus-or-minus value added to and subtracted from the sample statistic (like a mean or proportion) to create the confidence interval.
# Confidence Interval=Point Estimate±Margin of Error
# So, the margin of error defines how wide the confidence interval is.
#
# How Margin of Error Affects the Confidence Interval
# Larger MOE = Wider confidence interval = More uncertainty
#
# Smaller MOE = Narrower confidence interval = More precision
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#
# ans. Bayes' Theorem is a cornerstone of probability theory and statistics, especially when dealing with uncertainty and updating beliefs based on new evidence.
#
# Hypothesis testing: Updating the probability that a hypothesis is true given observed data.
#
# Medical testing:
#
# How likely is a person to have a disease given a positive test result?
#
# Bayes’ Theorem accounts for false positives/negatives and base rates.
#
# Spam filtering: Estimating the probability that an email is spam based on the words it contains.
#
# Machine learning: Naive Bayes classifiers use this logic to make predictions.
#
# Bayesian statistics:
#
# Unlike classical (frequentist) stats, Bayesian methods incorporate prior knowledge and update it with data.
#
# Leads to a posterior distribution, which reflects both the data and the prior beliefs.
#
# 17. What is the Chi-square distribution, and when is it used ?
#
# ans. The Chi-square distribution is:
#
# A family of skewed right distributions (shape depends on degrees of freedom)
#
# Defined only for non-negative values (starts at 0 and goes to ∞)
#
# Used when working with squared differences (which are always positive)
# When Do We Use the Chi-square Distribution?
# Chi-square is used in hypothesis testing involving counts or frequencies, not means or variances. Common uses:
#
# Chi-square Goodness-of-Fit Test
# Checks whether a single categorical variable fits a specific distribution.
#
# Example: Do dice rolls occur with equal probability?
#
# Chi-square Test of Independence
# Tests whether two categorical variables are independent.
#
# Example: Is there a relationship between gender and voting preference?
#
# Chi-square Test for Homogeneity
# Compares distributions of a categorical variable across multiple populations.
#
# Example: Are product preferences the same across three cities?
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#
# ans. The Chi-square goodness of fit test is a statistical test used to determine whether a set of observed categorical data matches an expected distribution. It helps answer questions like:
#
# "Does this sample data fit what we would expect if everything were fair or random?"
#
# When to Use It
# You have one categorical variable with two or more categories
#
# You have observed frequencies for each category
#
# You want to compare them to expected frequencies under some hypothesis
#
# 19.  What is the F-distribution, and when is it used in hypothesis testing?
#
# ans. The F-distribution is a probability distribution that arises frequently in statistics, especially when comparing variances between two groups or evaluating multiple group means in ANOVA (Analysis of Variance).
#
# When Is the F-distribution Used?
#   1). Comparing Variances
# F-test for equality of variances
#
# Example: Is the variability in test scores different between two schools?
#
#  2). ANOVA (Analysis of Variance)
# The most common use
#
# Tests whether three or more group means are significantly different
#
# Example: Do different diets result in different average weight loss?
#
#  3). Regression Analysis
# Used in overall F-test to assess whether a regression model explains a significant portion of the variance in the outcome variable.
#
# 20. What is an ANOVA test, and what are its assumptions?
#
# ans. ANOVA stands for Analysis of Variance. It’s a statistical test used to determine whether there are statistically significant differences between the means of three or more independent groups.
#
#   Assumptions of ANOVA
#   1)Independence
#
# Observations in each group must be independent of each other.
#
#   2)Normality
#
# The data in each group should be approximately normally distributed.
#
# This is especially important if the sample size is small.
#
#   3)Homogeneity of variance (homoscedasticity)
#
# All groups should have similar variances.
#
# You can check this with Levene’s Test or Bartlett’s Test.
#
#
# 21. What are the different types of ANOVA tests ?
#
# ans. 1)One-Way ANOVA (Single Factor ANOVA)
# Purpose: Compare the means of 3 or more groups based on 1 independent variable (factor).
#
#   2)Two-Way ANOVA (Factorial ANOVA)
# Purpose: Compare means across groups defined by two independent variables, and test for interaction between them.
#
#   3)Repeated Measures ANOVA
# Purpose: Used when the same subjects are measured multiple times (within-subjects design).
#
#   4)Mixed-Design ANOVA (Split-Plot ANOVA)
# Purpose: Combines between-subjects and within-subjects factors.
#
#   5) MANOVA (Multivariate Analysis of Variance)
# Purpose: Extension of ANOVA when there are multiple dependent variables.
#
#   6)ANCOVA (Analysis of Covariance)
# Purpose: Like ANOVA, but controls for one or more continuous variables (covariates) that might affect the dependent variable.
#
# 22.What is the F-test, and how does it relate to hypothesis testing?
#
# ans. The F-test tests whether the variances between two or more groups are significantly different. It compares the ratio of two variances (or mean squares) and follows an F-distribution, which is based on degrees of freedom.

# %%
# Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and
#interpret the results
import numpy as np
from scipy import stats


def z_test(sample_data, population_mean, population_std, sample_size):

    sample_mean = np.mean(sample_data)


    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))


    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))


    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"P-value: {p_value:.4f}")


    alpha = 0.05
    if p_value < alpha:
        print(f"Reject the null hypothesis: There is a significant difference between the sample mean and the population mean.")
    else:
        print(f"Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")

sample_data = [50, 52, 51, 54, 50, 49, 53, 55, 50, 51]
population_mean = 50
population_std = 2
sample_size = len(sample_data)
z_test(sample_data, population_mean, population_std, sample_size)
# Out:
# Sample Mean: 51.50
# Z-statistic: 2.37
# P-value: 0.0177
# Reject the null hypothesis: There is a significant difference between the sample mean and the population mean.

# %%
#Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt


def simulate_and_test(population_mean, population_std, sample_size):

    sample_data = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)


    sample_mean = np.mean(sample_data)

    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))


    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))


    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"P-value: {p_value:.4f}")


    alpha = 0.05
    if p_value < alpha:
        print(f"Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print(f"Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.")


    plt.hist(sample_data, bins=10, edgecolor='black', alpha=0.7)
    plt.axvline(x=population_mean, color='r', linestyle='dashed', linewidth=2, label="Population Mean")
    plt.axvline(x=sample_mean, color='b', linestyle='dashed', linewidth=2, label="Sample Mean")
    plt.title("Histogram of Simulated Data")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.show()

population_mean = 50
population_std = 10
sample_size = 100

simulate_and_test(population_mean, population_std, sample_size)
# Out:
# Sample Mean: 49.14
# Z-statistic: -0.86
# P-value: 0.3887
# Fail to reject the null hypothesis: There is no significant difference between the sample mean and the population mean.

# %%
# Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
import numpy as np
from scipy import stats

def one_sample_z_test(sample_data, population_mean, population_std):

    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))


    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))


    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"P-value: {p_value:.4f}")

    alpha = 0.05
    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")

sample_data = np.random.normal(loc=52, scale=8, size=30)
population_mean = 50
population_std = 8
one_sample_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 49.34
# Z-statistic: -0.45
# P-value: 0.6525
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
# Perform a two-tailed Z-test using Python and visualize the decision region on a plot

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats


def two_tailed_z_test(sample_data, population_mean, population_std):

    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)


    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    alpha = 0.05
    z_critical = stats.norm.ppf(1 - alpha / 2)

    p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))


    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"P-value: {p_value:.4f}")


    if p_value < alpha:
        print("Reject the null hypothesis: The sample mean is significantly different from the population mean.")
    else:
        print("Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.")


    plot_decision_region(z_statistic, z_critical, alpha)


def plot_decision_region(z_statistic, z_critical, alpha):

    z_values = np.linspace(-4, 4, 1000)
    normal_pdf = stats.norm.pdf(z_values)


    plt.figure(figsize=(10, 6))
    plt.plot(z_values, normal_pdf, label='Standard Normal Distribution', color='b')


    plt.fill_between(z_values, normal_pdf, where=(z_values <= -z_critical), color='red', alpha=0.5)
    plt.fill_between(z_values, normal_pdf, where=(z_values >= z_critical), color='red', alpha=0.5)


    plt.axvline(x=z_statistic, color='g', linestyle='--', label=f"Z-statistic = {z_statistic:.2f}")


    plt.axvline(x=-z_critical, color='r', linestyle='--', label=f"Critical Z = {-z_critical:.2f}")
    plt.axvline(x=z_critical, color='r', linestyle='--', label=f"Critical Z = {z_critical:.2f}")

    plt.title(f"Two-Tailed Z-test (α = 0.05)")
    plt.xlabel("Z-value")
    plt.ylabel("Probability Density")
    plt.legend(loc='upper left')
    plt.grid(True)
    plt.show()


sample_data = np.random.normal(loc=52, scale=8, size=30)
population_mean = 50
population_std = 8
two_tailed_z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 50.78
# Z-statistic: 0.53
# P-value: 0.5939
# Fail to reject the null hypothesis: The sample mean is not significantly different from the population mean.

# %%
# Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def visualize_type1_type2_errors(mu_null, mu_alt, sigma, n, alpha=0.05, test_type='right'):
    """
    Visualize Type I and Type II errors for a one-sample Z-test.

    Parameters:
    - mu_null: Mean under the null hypothesis (H0)
    - mu_alt: Mean under the alternative hypothesis (H1)
    - sigma: Population standard deviation
    - n: Sample size
    - alpha: Significance level (default = 0.05)
    - test_type: 'left', 'right', or 'two-tailed'
    """

    se = sigma / np.sqrt(n)

    if test_type == 'right':
        z_crit = norm.ppf(1 - alpha)
        critical_value = mu_null + z_crit * se
    elif test_type == 'left':
        z_crit = norm.ppf(alpha)
        critical_value = mu_null + z_crit * se
    elif test_type == 'two-tailed':
        z_crit = norm.ppf(1 - alpha / 2)
        critical_value_right = mu_null + z_crit * se
        critical_value_left = mu_null - z_crit * se
    else:
        raise ValueError("test_type must be 'left', 'right', or 'two-tailed'")


    x = np.linspace(mu_null - 4*se, mu_alt + 4*se, 1000)


    null_pdf = norm.pdf(x, mu_null, se)
    alt_pdf = norm.pdf(x, mu_alt, se)


    plt.figure(figsize=(10, 6))
    plt.plot(x, null_pdf, label='Null Hypothesis (H₀)', color='blue')
    plt.plot(x, alt_pdf, label='Alternative Hypothesis (H₁)', color='green')


    if test_type == 'right':
        plt.fill_between(x, 0, null_pdf, where=(x >= critical_value), color='red', alpha=0.3, label='Type I Error (α)')
        plt.axvline(critical_value, color='red', linestyle='--')

        plt.fill_between(x, 0, alt_pdf, where=(x < critical_value), color='purple', alpha=0.3, label='Type II Error (β)')
    elif test_type == 'left':
        plt.fill_between(x, 0, null_pdf, where=(x <= critical_value), color='red', alpha=0.3, label='Type I Error (α)')
        plt.axvline(critical_value, color='red', linestyle='--')
        plt.fill_between(x, 0, alt_pdf, where=(x > critical_value), color='purple', alpha=0.3, label='Type II Error (β)')
    elif test_type == 'two-tailed':
        plt.axvline(critical_value_right, color='red', linestyle='--')
        plt.axvline(critical_value_left, color='red', linestyle='--')
        plt.fill_between(x, 0, null_pdf, where=(x >= critical_value_right) | (x <= critical_value_left), color='red', alpha=0.3, label='Type I Error (α)')
        plt.fill_between(x, 0, alt_pdf, where=(x < critical_value_right) & (x > critical_value_left), color='purple', alpha=0.3, label='Type II Error (β)')

    plt.title("Type I and Type II Errors in Hypothesis Testing")
    plt.xlabel("Sample Mean")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()


visualize_type1_type2_errors(
    mu_null=100,
    mu_alt=105,
    sigma=15,
    n=30,
    alpha=0.05,
    test_type='right'
)

# %%
# Write a Python program to perform an independent T-test and interpret the results.
import numpy as np
from scipy import stats

def independent_t_test(group1, group2, equal_var=True):
    """
    Perform an independent two-sample t-test and interpret the results.

    Parameters:
    - group1: list or array of numeric values (sample 1)
    - group2: list or array of numeric values (sample 2)
    - equal_var: boolean, True for standard t-test, False for Welch's t-test
    """

    t_stat, p_value = stats.ttest_ind(group1, group2, equal_var=equal_var)


    print(f"Group 1 mean: {np.mean(group1):.2f}")
    print(f"Group 2 mean: {np.mean(group2):.2f}")
    print(f"T-statistic: {t_stat:.3f}")
    print(f"P-value: {p_value:.4f}")


    alpha = 0.05
    if p_value < alpha:
        print("Reject the null hypothesis: The group means are significantly different.")
    else:
        print("Fail to reject the null hypothesis: No significant difference between the group means.")


np.random.seed(42)
group1 = np.random.normal(loc=75, scale=10, size=30)
group2 = np.random.normal(loc=80, scale=10, size=30)

independent_t_test(group1, group2, equal_var=True)
# Out:
# Group 1 mean: 73.12
# Group 2 mean: 78.79
# T-statistic: -2.398
# P-value: 0.0197
# Reject the null hypothesis: The group means are significantly different.

# %%
 #  Perform a paired sample T-test using Python and visualize the comparison results.

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

def paired_t_test(before, after):
    """
    Perform a paired sample t-test and visualize the results.

    Parameters:
    - before: scores or measurements before treatment
    - after: scores or measurements after treatment
    """
    # Perform paired t-test
    t_stat, p_value = stats.ttest_rel(before, after)

    # Summary statistics
    mean_before = np.mean(before)
    mean_after = np.mean(after)

    # Print results
    print(f"Mean Before: {mean_before:.2f}")
    print(f"Mean After:  {mean_after:.2f}")
    print(f"T-statistic: {t_stat:.3f}")
    print(f"P-value: {p_value:.4f}")

    # Interpret result
    alpha = 0.05
    if p_value < alpha:
        print("✅ Reject the null hypothesis: There is a significant difference.")
    else:
        print("❌ Fail to reject the null hypothesis: No significant difference.")

    # Visualize the comparison
    plt.figure(figsize=(8, 5))
    plt.plot([1]*len(before), before, 'bo', label='Before')
    plt.plot([2]*len(after), after, 'go', label='After')
    for i in range(len(before)):
        plt.plot([1, 2], [before[i], after[i]], 'k-', alpha=0.3)
    plt.xticks([1, 2], ['Before', 'After'])
    plt.ylabel('Score')
    plt.title('Paired Sample T-test: Before vs After')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Simulated data: scores before and after a training program
np.random.seed(42)
before_scores = np.random.normal(loc=70, scale=8, size=25)
after_scores = before_scores + np.random.normal(loc=5, scale=5, size=25)

# Run the test
paired_t_test(before_scores, after_scores)
# Out:
# Mean Before: 68.69
# Mean After:  72.25
# T-statistic: -3.849
# P-value: 0.0008
# ✅ Reject the null hypothesis: There is a significant difference.

# %%
#  Simulate data and perform both Z-test and T-test, then compare the results using Python.
import numpy as np
from scipy import stats

def simulate_and_compare_tests(mu_population=100, sigma_population=15, sample_size=30, alpha=0.05):
    # Simulate data
    np.random.seed(42)
    sample = np.random.normal(loc=mu_population + 3, scale=sigma_population, size=sample_size)  # slight shift

    # Known population mean and std deviation
    mu_0 = mu_population
    sigma = sigma_population
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)

    print(f"\nSample Mean: {sample_mean:.2f}")
    print(f"Sample Std Dev: {sample_std:.2f}")
    print(f"Population Mean (μ₀): {mu_0}")
    print(f"Sample Size: {sample_size}\n")

    # Z-test (known population std deviation)
    z_stat = (sample_mean - mu_0) / (sigma / np.sqrt(sample_size))
    p_z = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    # T-test (unknown population std deviation)
    t_stat, p_t = stats.ttest_1samp(sample, popmean=mu_0)

    # Results
    print("Z-test results (population std known):")
    print(f"Z-statistic: {z_stat:.3f}")
    print(f"P-value: {p_z:.4f}")
    print("=>", "Reject H₀" if p_z < alpha else "Fail to reject H₀")

    print("\nT-test results (population std estimated):")
    print(f"T-statistic: {t_stat:.3f}")
    print(f"P-value: {p_t:.4f}")
    print("=>", "Reject H₀" if p_t < alpha else "Fail to reject H₀")

# Run the comparison
simulate_and_compare_tests()
# Out:
# Sample Mean: 100.18
# Sample Std Dev: 13.50
# Population Mean (μ₀): 100
# Sample Size: 30
#
# Z-test results (population std known):
# Z-statistic: 0.065
# P-value: 0.9482
# => Fail to reject H₀
#
# T-test results (population std estimated):
# T-statistic: 0.072
# P-value: 0.9430
# => Fail to reject H₀

# %%
# Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
    - data: list or numpy array of sample observations
    - confidence: confidence level (default = 0.95)

    Returns:
    - (lower_bound, upper_bound): tuple representing the confidence interval
    """
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)  # Standard error of the mean
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)  # t-critical value

    margin_of_error = t_crit * std_err
    ci_lower = mean - margin_of_error
    ci_upper = mean + margin_of_error

    print(f"Sample Mean: {mean:.2f}")
    print(f"Confidence Level: {confidence*100:.0f}%")
    print(f"Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")

    return (ci_lower, ci_upper)

# Example usage with simulated data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=25)
confidence_interval(sample_data, confidence=0.95)
# Out:
# Sample Mean: 48.36
# Confidence Level: 95%
# Confidence Interval: (44.42, 52.31)
# (np.float64(44.41646246765881), np.float64(52.31337635917938))

# %%
# Write a Python program to calculate the margin of error for a given confidence level using sample data.
import numpy as np
from scipy import stats

def calculate_margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level using sample data.

    Parameters:
    - data: list or numpy array of sample observations
    - confidence: confidence level (default = 0.95)

    Returns:
    - margin_of_error: the calculated margin of error
    """
    n = len(data)
    std_err = stats.sem(data)  # Standard error of the mean
    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)  # t-critical value

    margin_of_error = t_crit * std_err
    print(f"Sample Size: {n}")
    print(f"Standard Error: {std_err:.4f}")
    print(f"T-critical value (df={n-1}): {t_crit:.4f}")
    print(f"Margin of Error at {int(confidence * 100)}% confidence: ±{margin_of_error:.2f}")
    return margin_of_error

# Example usage with simulated sample data
np.random.seed(1)
sample_data = np.random.normal(loc=70, scale=12, size=40)
calculate_margin_of_error(sample_data, confidence=0.95)
# Out:
# Sample Size: 40
# Standard Error: 1.8535
# T-critical value (df=39): 2.0227
# Margin of Error at 95% confidence: ±3.75
# np.float64(3.749083932864603)

# %%
# Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
def bayes_theorem(prior, sensitivity, specificity):
    """
    Apply Bayes' Theorem to a diagnostic test scenario.

    Parameters:
    - prior: prior probability of having the disease (e.g., 0.01)
    - sensitivity: P(Test+ | Disease) — true positive rate
    - specificity: P(Test- | No Disease) — true negative rate

    Returns:
    - posterior: P(Disease | Test+)
    """
    # Prior probabilities
    P_D = prior
    P_not_D = 1 - P_D

    # Likelihoods
    P_pos_given_D = sensitivity
    P_pos_given_not_D = 1 - specificity

    # Marginal probability of a positive test
    P_pos = (P_pos_given_D * P_D) + (P_pos_given_not_D * P_not_D)

    # Posterior using Bayes' Theorem
    P_D_given_pos = (P_pos_given_D * P_D) / P_pos

    print(f"Posterior Probability P(Disease | Test+): {P_D_given_pos:.4f}")
    return P_D_given_pos

# Example usage
prior_prob = 0.01         # 1% disease prevalence
sensitivity = 0.99        # True positive rate
specificity = 0.95        # True negative rate

bayes_theorem(prior_prob, sensitivity, specificity)
# Out:
# Posterior Probability P(Disease | Test+): 0.1667
# 0.16666666666666655

# %%
# Perform a Chi-square test for independence between two categorical variables in Python.
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

def chi_square_independence_test():
    # Example contingency table (observed frequencies)
    data = {
        "Tea":    [30, 20],  # [Male, Female]
        "Coffee": [20, 30]
    }
    df = pd.DataFrame(data, index=["Male", "Female"])

    print("Contingency Table:\n", df)

    # Perform Chi-square test
    chi2, p, dof, expected = chi2_contingency(df)

    # Results
    print(f"\nChi-square statistic: {chi2:.3f}")
    print(f"Degrees of freedom: {dof}")
    print(f"P-value: {p:.4f}")
    print("\nExpected frequencies:\n", pd.DataFrame(expected, index=df.index, columns=df.columns))


    alpha = 0.05
    if p < alpha:
        print("\nReject the null hypothesis: Variables are dependent.")
    else:
        print("\n Fail to reject the null hypothesis: Variables are independent.")
chi_square_independence_test()
# Out:
# Contingency Table:
#          Tea  Coffee
# Male     30      20
# Female   20      30
#
# Chi-square statistic: 3.240
# Degrees of freedom: 1
# P-value: 0.0719
#
# Expected frequencies:
#           Tea  Coffee
# Male    25.0    25.0
# Female  25.0    25.0
#
#  Fail to reject the null hypothesis: Variables are independent.

# %%
# Write a Python program to calculate the expected frequencies for a Chi-square test based on observed
#data
import pandas as pd
import numpy as np

def calculate_expected_frequencies(observed_data):
    """
    Calculate the expected frequencies for a Chi-square test given observed data.

    Parameters:
    - observed_data: Pandas DataFrame of observed frequencies

    Returns:
    - expected_df: DataFrame of expected frequencies
    """
    # Convert to DataFrame if not already
    if not isinstance(observed_data, pd.DataFrame):
        observed_data = pd.DataFrame(observed_data)

    # Calculate row totals, column totals, and grand total
    row_totals = observed_data.sum(axis=1)
    col_totals = observed_data.sum(axis=0)
    grand_total = observed_data.values.sum()

    # Compute expected frequencies
    expected = np.outer(row_totals, col_totals) / grand_total
    expected_df = pd.DataFrame(expected, index=observed_data.index, columns=observed_data.columns)

    print("Observed Frequencies:\n", observed_data)
    print("\nExpected Frequencies:\n", expected_df.round(2))

    return expected_df

# Example observed data
observed = pd.DataFrame({
    "Tea":    [30, 20],
    "Coffee": [20, 30]
}, index=["Male", "Female"])

# Calculate expected frequencies
calculate_expected_frequencies(observed)
# Out:
# Observed Frequencies:
#          Tea  Coffee
# Male     30      20
# Female   20      30
#
# Expected Frequencies:
#           Tea  Coffee
# Male    25.0    25.0
# Female  25.0    25.0
#          Tea  Coffee
# Male    25.0    25.0
# Female  25.0    25.0

# %%
#  Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution .
import numpy as np
from scipy.stats import chisquare

def chi_square_goodness_of_fit(observed, expected=None):
    """
    Perform a Chi-square goodness-of-fit test.

    Parameters:
    - observed: list or array of observed frequencies
    - expected: list or array of expected frequencies (optional)

    Returns:
    - Chi-square statistic and p-value
    """
    observed = np.array(observed)

    if expected is None:
        # If expected is not given, assume uniform distribution
        expected = np.full_like(observed, fill_value=observed.sum() / len(observed))

    chi2_stat, p_value = chisquare(f_obs=observed, f_exp=expected)

    print("Observed:", observed)
    print("Expected:", expected)
    print(f"\nChi-square statistic: {chi2_stat:.3f}")
    print(f"P-value: {p_value:.4f}")

    if p_value < 0.05:
        print("Reject the null hypothesis: The data does not fit the expected distribution.")
    else:
        print(" Fail to reject the null hypothesis: The data fits the expected distribution.")

    return chi2_stat, p_value

# Example: Test if a die is fair
observed_rolls = [8, 9, 10, 11, 12, 10]
chi_square_goodness_of_fit(observed_rolls)
# Out:
# Observed: [ 8  9 10 11 12 10]
# Expected: [10 10 10 10 10 10]
#
# Chi-square statistic: 1.000
# P-value: 0.9626
#  Fail to reject the null hypothesis: The data fits the expected distribution.
# (np.float64(1.0), np.float64(0.9625657732472964))

# %%
# Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

def visualize_chi_square(df_list, size=10000):
    """
    Simulate and visualize the Chi-square distribution for multiple degrees of freedom (df).

    Parameters:
    - df_list: List of degrees of freedom for the Chi-square distributions
    - size: Number of samples to simulate
    """
    plt.figure(figsize=(10, 6))

    # Simulate and plot Chi-square distributions for different df
    for df in df_list:
        # Generate chi-square data for the given degrees of freedom
        data = np.random.chisquare(df, size)

        # Plot histogram
        plt.hist(data, bins=50, alpha=0.5, label=f'df={df}', density=True)

        # Overlay the theoretical Chi-square pdf for comparison
        x = np.linspace(0, np.max(data), 1000)
        plt.plot(x, chi2.pdf(x, df), label=f'Theoretical df={df}', linestyle='--')

    plt.title("Chi-square Distribution for Different Degrees of Freedom")
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage: Visualize Chi-square distributions for df=1, 2, 5, and 10
df_list = [1, 2, 5, 10]
visualize_chi_square(df_list)

# %%
#  Implement an F-test using Python to compare the variances of two random samples.
import numpy as np
from scipy.stats import f

def f_test_variance(sample1, sample2):
    """
    Perform an F-test to compare the variances of two samples.

    Parameters:
    - sample1: list or numpy array of data for sample 1
    - sample2: list or numpy array of data for sample 2

    Returns:
    - F-statistic and p-value
    """

    var1 = np.var(sample1, ddof=1)
    var2 = np.var(sample2, ddof=1)

    n1 = len(sample1)
    n2 = len(sample2)

    f_stat = var1 / var2 if var1 > var2 else var2 / var1

    df1 = n1 - 1
    df2 = n2 - 1


    p_value = 1 - f.cdf(f_stat, df1, df2)

    print(f"Variance of Sample 1: {var1:.3f}")
    print(f"Variance of Sample 2: {var2:.3f}")
    print(f"F-statistic: {f_stat:.3f}")
    print(f"P-value: {p_value:.4f}")

    alpha = 0.05
    if p_value < alpha:
        print("\n Reject the null hypothesis: The variances are significantly different.")
    else:
        print("\n Fail to reject the null hypothesis: The variances are not significantly different.")

    return f_stat, p_value
np.random.seed(42)
sample1 = np.random.normal(loc=50, scale=10, size=30)
sample2 = np.random.normal(loc=55, scale=15, size=30)

f_test_variance(sample1, sample2)
# Out:
# Variance of Sample 1: 81.001
# Variance of Sample 2: 195.064
# F-statistic: 2.408
# P-value: 0.0104
#
#  Reject the null hypothesis: The variances are significantly different.
# (np.float64(2.408163667127679), np.float64(0.010437797725393105))

# %%
# Write a Python program to perform an ANOVA test to compare means between multiple groups and
#interpret the results.
import numpy as np
from scipy.stats import f_oneway

def anova_test(group1, group2, group3):
    """
    Perform a One-Way ANOVA test to compare means between multiple groups.

    Parameters:
    - group1: data for group 1 (numpy array or list)
    - group2: data for group 2 (numpy array or list)
    - group3: data for group 3 (numpy array or list)

    Returns:
    - F-statistic and p-value
    """
    # Perform One-Way ANOVA
    f_stat, p_value = f_oneway(group1, group2, group3)

    print(f"F-statistic: {f_stat:.3f}")
    print(f"P-value: {p_value:.4f}")

    # Hypothesis testing
    alpha = 0.05
    if p_value < alpha:
        print("\n Reject the null hypothesis: There is a significant difference between group means.")
    else:
        print("\n Fail to reject the null hypothesis: There is no significant difference between group means.")

    return f_stat, p_value

# Example data: Scores of students from three different study methods
np.random.seed(42)
group1 = np.random.normal(loc=75, scale=10, size=30)
group2 = np.random.normal(loc=80, scale=12, size=30)
group3 = np.random.normal(loc=70, scale=8, size=30)


anova_test(group1, group2, group3)
# Out:
# F-statistic: 6.129
# P-value: 0.0032
#
#  Reject the null hypothesis: There is a significant difference between group means.
# (np.float64(6.128710592241623), np.float64(0.00323517315185994))

# %%
#  Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results .
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

def anova_test_and_plot(group1, group2, group3):
    """
    Perform a One-Way ANOVA test and plot the results.

    Parameters:
    - group1: data for group 1 (numpy array or list)
    - group2: data for group 2 (numpy array or list)
    - group3: data for group 3 (numpy array or list)
    """
    # Perform One-Way ANOVA
    f_stat, p_value = f_oneway(group1, group2, group3)

    # Results of ANOVA
    print(f"F-statistic: {f_stat:.3f}")
    print(f"P-value: {p_value:.4f}")

    # Hypothesis testing
    alpha = 0.05
    if p_value < alpha:
        print("\n Reject the null hypothesis: There is a significant difference between group means.")
    else:
        print("\n Fail to reject the null hypothesis: There is no significant difference between group means.")

    # Plot the boxplots
    plt.figure(figsize=(8, 6))
    plt.boxplot([group1, group2, group3], labels=["Method 1", "Method 2", "Method 3"])
    plt.title("Boxplot of Scores for Different Study Methods")
    plt.ylabel("Scores")
    plt.grid(True)
    plt.show()

    return f_stat, p_value


np.random.seed(42)
group1 = np.random.normal(loc=75, scale=10, size=30)  # Study Method 1
group2 = np.random.normal(loc=80, scale=12, size=30)  # Study Method 2
group3 = np.random.normal(loc=70, scale=8, size=30)   # Study Method 3


anova_test_and_plot(group1, group2, group3)
# Out:
# F-statistic: 6.129
# P-value: 0.0032
#
#  Reject the null hypothesis: There is a significant difference between group means.
# <ipython-input-22-37825ec73675>:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=["Method 1", "Method 2", "Method 3"])
# (np.float64(6.128710592241623), np.float64(0.00323517315185994))

# %%
# Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import shapiro, levene, probplot

def check_anova_assumptions(groups):
    """
    Check the assumptions for ANOVA: normality, independence, and equal variance.

    Parameters:
    - groups: list of groups (each group should be a numpy array or list of data)

    Returns:
    - None
    """
    # Check normality assumption using Shapiro-Wilk test for each group
    print("Checking normality using Shapiro-Wilk test:")
    for i, group in enumerate(groups):
        stat, p_value = shapiro(group)
        print(f"Group {i+1}: Shapiro-Wilk statistic = {stat:.4f}, p-value = {p_value:.4f}")
        if p_value < 0.05:
            print(f"  Group {i+1} does not follow normal distribution (p < 0.05)")
        else:
            print(f"   Group {i+1} follows normal distribution (p >= 0.05)")

    # Plot Q-Q plots to visually assess normality
    plt.figure(figsize=(12, 8))
    for i, group in enumerate(groups):
        plt.subplot(1, len(groups), i+1)
        probplot(group, dist="norm", plot=plt)
        plt.title(f"Group {i+1} Q-Q Plot")
    plt.tight_layout()
    plt.show()

    # Check equality of variances using Levene's test
    print("\nChecking equality of variances using Levene's test:")
    stat, p_value = levene(*groups)
    print(f"Levene's statistic = {stat:.4f}, p-value = {p_value:.4f}")
    if p_value < 0.05:
        print("  Variances are not equal (p < 0.05)")
    else:
        print("  Variances are equal (p >= 0.05)")

# Example usage with data for three groups
np.random.seed(42)
group1 = np.random.normal(loc=75, scale=10, size=30)  # Study Method 1
group2 = np.random.normal(loc=80, scale=12, size=30)  # Study Method 2
group3 = np.random.normal(loc=70, scale=8, size=30)   # Study Method 3

# Check ANOVA assumptions
check_anova_assumptions([group1, group2, group3])
# Out:
# Checking normality using Shapiro-Wilk test:
# Group 1: Shapiro-Wilk statistic = 0.9751, p-value = 0.6868
#    Group 1 follows normal distribution (p >= 0.05)
# Group 2: Shapiro-Wilk statistic = 0.9837, p-value = 0.9130
#    Group 2 follows normal distribution (p >= 0.05)
# Group 3: Shapiro-Wilk statistic = 0.9628, p-value = 0.3654
#    Group 3 follows normal distribution (p >= 0.05)
# Checking equality of variances using Levene's test:
# Levene's statistic = 2.3198, p-value = 0.1043
#   Variances are equal (p >= 0.05)

# %%
# Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

def visualize_f_distribution(df1, df2):
    """
    Visualizes the F-distribution for given degrees of freedom df1 and df2.

    Parameters:
    - df1: degrees of freedom for the numerator (between-group variance)
    - df2: degrees of freedom for the denominator (within-group variance)
    """
    # Create an array of x values (possible F-statistic values)
    x = np.linspace(0, 5, 500)

    # Calculate the F-distribution for the given degrees of freedom
    y = stats.f.pdf(x, df1, df2)

    # Plotting the F-distribution
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label=f'F-distribution df1={df1}, df2={df2}', color='blue')

    # Mark the critical value for a 0.05 significance level (right tail)
    critical_value = stats.f.ppf(0.95, df1, df2)
    plt.axvline(critical_value, color='red', linestyle='dashed', label=f'Critical Value (95%): {critical_value:.2f}')

    plt.title(f'F-Distribution with df1={df1} and df2={df2}')
    plt.xlabel('F-statistic')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Visualize the F-distribution for different degrees of freedom
df1 = 5  # degrees of freedom for the numerator
df2 = 10 # degrees of freedom for the denominator

visualize_f_distribution(df1, df2)

# %%
 #  Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.
 import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Simulate Data
np.random.seed(42)

# Simulating three groups with different means
group1 = np.random.normal(loc=60, scale=10, size=30)  # Group 1 (Mean = 60)
group2 = np.random.normal(loc=70, scale=12, size=30)  # Group 2 (Mean = 70)
group3 = np.random.normal(loc=80, scale=15, size=30)  # Group 3 (Mean = 80)

# Step 2: Perform One-Way ANOVA
f_stat, p_value = stats.f_oneway(group1, group2, group3)

# Display the results of the ANOVA test
print(f"F-statistic: {f_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 3: Visualize the results with boxplots
plt.figure(figsize=(8, 6))
sns.boxplot(data=[group1, group2, group3],
            palette="Set3",
            boxprops=dict(facecolor="lightblue"))

# Adding titles and labels
plt.title("One-Way ANOVA: Comparison of Group Means")
plt.xticks([0, 1, 2], ['Group 1', 'Group 2', 'Group 3'])
plt.ylabel("Values")
plt.xlabel("Groups")
plt.grid(True)
plt.show()

# Interpretation of results
if p_value < 0.05:
    print("\nThere is a significant difference between the group means.")
else:
    print("\nThere is no significant difference between the group means.")
# Out:
# F-statistic: 25.688
# P-value: 0.0000
# There is a significant difference between the group means.

# %%
# Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Step 1: Simulate random data from normal distributions
np.random.seed(42)

# Group 1: Mean = 50, Standard deviation = 10, Sample size = 100
group1 = np.random.normal(loc=50, scale=10, size=100)

# Group 2: Mean = 55, Standard deviation = 10, Sample size = 100
group2 = np.random.normal(loc=55, scale=10, size=100)

# Step 2: Perform a two-sample t-test to evaluate the means
t_stat, p_value = stats.ttest_ind(group1, group2)

# Step 3: Display the results
print(f"T-statistic: {t_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Interpretation of results
if p_value < 0.05:
    print("\nReject the null hypothesis: There is a significant difference between the means of the two groups.")
else:
    print("\nFail to reject the null hypothesis: There is no significant difference between the means of the two groups.")

# Step 4: Visualize the data
plt.figure(figsize=(8, 6))
plt.hist(group1, alpha=0.5, bins=20, label='Group 1 (Mean=50)', color='blue')
plt.hist(group2, alpha=0.5, bins=20, label='Group 2 (Mean=55)', color='orange')
plt.legend()
plt.title('Distribution of Group 1 and Group 2')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
# Out:
# T-statistic: -4.755
# P-value: 0.0000
#
# Reject the null hypothesis: There is a significant difference between the means of the two groups.

# %%
 #  Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.
 import numpy as np
import scipy.stats as stats

# Step 1: Simulate random data from a normal distribution
np.random.seed(42)

# Simulate sample data with a true variance of 25 (standard deviation = 5)
sample_size = 30
true_variance = 25
sample_data = np.random.normal(loc=0, scale=5, size=sample_size)

# Step 2: Perform the Chi-square test for population variance
sample_variance = np.var(sample_data, ddof=1)  # sample variance (unbiased)
hypothesized_variance = 25  # hypothesized population variance

# Calculate the Chi-square test statistic
chi_square_stat = (sample_size - 1) * sample_variance / hypothesized_variance

# Step 3: Find the p-value using the Chi-square distribution
degrees_of_freedom = sample_size - 1
p_value = 2 * min(stats.chi2.cdf(chi_square_stat, degrees_of_freedom),
                  1 - stats.chi2.cdf(chi_square_stat, degrees_of_freedom))

# Display the results
print(f"Chi-square statistic: {chi_square_stat:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 4: Interpretation of the results
alpha = 0.05  # significance level

if p_value < alpha:
    print("\nReject the null hypothesis: The population variance is different from the hypothesized value.")
else:
    print("\nFail to reject the null hypothesis: The population variance is not significantly different from the hypothesized value.")
# Out:
# Chi-square statistic: 23.490
# P-value: 0.4927
#
# Fail to reject the null hypothesis: The population variance is not significantly different from the hypothesized value.

# %%
# Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.
import numpy as np
import scipy.stats as stats

# Step 1: Simulate Data for Two Groups (Successes and Sample Sizes)
# Group 1: 100 successes out of 200 trials
successes1 = 100
n1 = 200

# Group 2: 120 successes out of 250 trials
successes2 = 120
n2 = 250

# Step 2: Calculate the sample proportions
p1 = successes1 / n1
p2 = successes2 / n2

# Step 3: Calculate the pooled proportion
p = (successes1 + successes2) / (n1 + n2)

# Step 4: Calculate the Z-statistic
z = (p1 - p2) / np.sqrt(p * (1 - p) * (1/n1 + 1/n2))

# Step 5: Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

# Step 6: Display the results
print(f"Z-statistic: {z:.3f}")
print(f"P-value: {p_value:.4f}")

# Step 7: Interpretation of results
alpha = 0.05  # Significance level

if p_value < alpha:
    print("\nReject the null hypothesis: The proportions are significantly different.")
else:
    print("\nFail to reject the null hypothesis: The proportions are not significantly different.")
# Out:
# Z-statistic: 0.422
# P-value: 0.6732
#
# Fail to reject the null hypothesis: The proportions are not significantly different.

# %%
# Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Function to perform the F-test
def f_test(data1, data2, alpha=0.05):
    # Calculate variances
    var1 = np.var(data1, ddof=1)
    var2 = np.var(data2, ddof=1)

    # Calculate the F-statistic (larger variance / smaller variance)
    F = var1 / var2 if var1 >= var2 else var2 / var1
    df1 = len(data1) - 1  # degrees of freedom for data1
    df2 = len(data2) - 1  # degrees of freedom for data2

    # Calculate the critical value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Perform the hypothesis test
    if F > critical_value:
        result = 'Reject the null hypothesis (variances are different)'
    else:
        result = 'Fail to reject the null hypothesis (variances are equal)'

    return F, critical_value, result

# Visualize the F-distribution and the F-statistic
def plot_f_distribution(df1, df2, F, critical_value):
    # Create an F-distribution plot
    x = np.linspace(0, 5, 1000)
    y = stats.f.pdf(x, df1, df2)

    plt.plot(x, y, label='F-distribution', color='blue')
    plt.axvline(x=critical_value, color='red', linestyle='--', label='Critical Value')
    plt.axvline(x=F, color='green', linestyle='--', label='Calculated F-statistic')

    plt.title('F-distribution and F-test Result')
    plt.xlabel('F value')
    plt.ylabel('Density')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example datasets
data1 = np.random.normal(loc=0, scale=1, size=100)  # Dataset 1
data2 = np.random.normal(loc=0, scale=2, size=100)  # Dataset 2

# Perform the F-test
F, critical_value, result = f_test(data1, data2, alpha=0.05)

# Output the result
print(f'F-statistic: {F}')
print(f'Critical Value: {critical_value}')
print(result)

# Plot the F-distribution and test results
plot_f_distribution(len(data1) - 1, len(data2) - 1, F, critical_value)
# Out:
# F-statistic: 4.375356895242442
# Critical Value: 1.3940612573481483
# Reject the null hypothesis (variances are different)
